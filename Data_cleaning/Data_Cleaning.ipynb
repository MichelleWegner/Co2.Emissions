# %%
import pandas as pd

# %% [markdown]
# **Import the dataset**

# %%
df_temp = pd.read_csv('../DataSets/all countries global temperature.csv')

# %%
df_temp
# Out:
#      ObjectId                  Country Name            Unit  \
# 0           1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1           2                       Albania  Degree Celsius
# 2           3                       Algeria  Degree Celsius
# 3           4                American Samoa  Degree Celsius
# 4           5      Andorra, Principality of  Degree Celsius
# ..        ...                           ...             ...
# 222       223                Western Sahara  Degree Celsius
# 223       224                         World  Degree Celsius
# 224       225                Yemen, Rep. of  Degree Celsius
# 225       226                        Zambia  Degree Celsius
# 226       230                      Zimbabwe  Degree Celsius
#
#                         Change    1970   1971   1972   1973   1974   1975  \
# 0    Surface Temperature Change  0.898  0.652 -1.089  0.262 -0.470 -0.468
# 1    Surface Temperature Change -0.119 -0.200 -0.077 -0.299 -0.134 -0.203
# ...

# %%
df_emisions = pd.read_csv('../DataSets/co2_emissions_kt_by_country.csv')

# %%
df_emisions
# Out:
#       country_code country_name  year         value
# 0              ABW        Aruba  1960  11092.675000
# 1              ABW        Aruba  1961  11576.719000
# 2              ABW        Aruba  1962  12713.489000
# 3              ABW        Aruba  1963  12178.107000
# 4              ABW        Aruba  1964  11840.743000
# ...            ...          ...   ...           ...
# 13948          ZWE     Zimbabwe  2015  12430.000305
# 13949          ZWE     Zimbabwe  2016  11020.000458
# 13950          ZWE     Zimbabwe  2017  10340.000153
# 13951          ZWE     Zimbabwe  2018  12380.000114
# 13952          ZWE     Zimbabwe  2019  11760.000229
#
# [13953 rows x 4 columns]

# %% [markdown]
# Check for null Values

# %%
df_temp.isnull().any()
# Out:
# ObjectId        False
# Country Name    False
# Unit            False
# Change          False
# 1970             True
# 1971             True
# 1972             True
# 1973             True
# 1974             True
# 1975             True
# 1976             True
# 1977             True
# 1978             True
# 1979             True
# 1980             True
# 1981             True
# 1982             True
# 1983             True
# 1984             True
# 1985             True
# 1986             True
# 1987             True
# 1988             True
# 1989             True
# 1990             True
# 1991             True
# 1992             True
# 1993             True
# 1994             True
# 1995             True
# 1996             True
# 1997             True
# 1998             True
# 1999             True
# 2000             True
# 2001             True
# 2002             True
# 2003             True
# 2004             True
# 2005             True
# 2006             True
# ...

# %% [markdown]
# Drop only of the complete row is na

# %%
df_temp.dropna(how='all')
# Out:
#      ObjectId                  Country Name            Unit  \
# 0           1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1           2                       Albania  Degree Celsius
# 2           3                       Algeria  Degree Celsius
# 3           4                American Samoa  Degree Celsius
# 4           5      Andorra, Principality of  Degree Celsius
# ..        ...                           ...             ...
# 222       223                Western Sahara  Degree Celsius
# 223       224                         World  Degree Celsius
# 224       225                Yemen, Rep. of  Degree Celsius
# 225       226                        Zambia  Degree Celsius
# 226       230                      Zimbabwe  Degree Celsius
#
#                         Change    1970   1971   1972   1973   1974   1975  \
# 0    Surface Temperature Change  0.898  0.652 -1.089  0.262 -0.470 -0.468
# 1    Surface Temperature Change -0.119 -0.200 -0.077 -0.299 -0.134 -0.203
# ...

# %% [markdown]
# Filling empty spaces with unknow and checking if there's still any NaN or Null value

# %%
df_temp.fillna("Unknown", inplace = True)
#df_temp.ffill("Unknown")
df_temp.isna().any()
# Out:
# /tmp/ipykernel_4076/1177376175.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_temp.fillna("Unknown", inplace = True)
# ObjectId        False
# Country Name    False
# Unit            False
# Change          False
# 1970            False
# 1971            False
# 1972            False
# 1973            False
# 1974            False
# 1975            False
# 1976            False
# 1977            False
# 1978            False
# 1979            False
# 1980            False
# 1981            False
# 1982            False
# 1983            False
# 1984            False
# 1985            False
# 1986            False
# 1987            False
# 1988            False
# 1989            False
# 1990            False
# 1991            False
# 1992            False
# 1993            False
# 1994            False
# ...

# %% [markdown]
# # Set the names of the columns to lower case and eliminate the empty spaces

# %%
def column_names(df_name):
    import pandas as pd
new_column_names = [column.strip().lower().replace(" ", "_") for column in df_temp.columns]
df_temp.columns = new_column_names

# %%
df_temp.column = column_names(df_temp)

# %%
df_temp
# Out:
#      objectid                  country_name            unit  \
# 0           1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1           2                       Albania  Degree Celsius
# 2           3                       Algeria  Degree Celsius
# 3           4                American Samoa  Degree Celsius
# 4           5      Andorra, Principality of  Degree Celsius
# ..        ...                           ...             ...
# 222       223                Western Sahara  Degree Celsius
# 223       224                         World  Degree Celsius
# 224       225                Yemen, Rep. of  Degree Celsius
# 225       226                        Zambia  Degree Celsius
# 226       230                      Zimbabwe  Degree Celsius
#
#                          change   1970   1971   1972   1973   1974   1975  \
# 0    Surface Temperature Change  0.898  0.652 -1.089  0.262  -0.47 -0.468
# 1    Surface Temperature Change -0.119   -0.2 -0.077 -0.299 -0.134 -0.203
# ...

# %%
#get the value of each column values
unique_values = df_temp['country_name'].unique()

# %%
unique_values
# Out:
# array(['Afghanistan, Islamic Rep. of', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra, Principality of', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Armenia, Rep. of',
#        'Aruba, Kingdom of the Netherlands', 'Australia', 'Austria',
#        'Azerbaijan, Rep. of', 'Bahamas, The', 'Bahrain, Kingdom of',
#        'Bangladesh', 'Barbados', 'Belarus, Rep. of', 'Belgium', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Cayman Islands', 'Central African Rep.',
#        'Chad', 'Chile', 'China, P.R.: Hong Kong', 'China, P.R.: Macao',
#        'China, P.R.: Mainland', 'Colombia', 'Comoros, Union of the',
#        'Congo, Dem. Rep. of the', 'Congo, Rep. of', 'Cook Islands',
# ...

# %%
df_temp.country_name.duplicated().any()
# Out:
# False

# %%
df_temp.columns
# Out:
# Index(['objectid', 'country_name', 'unit', 'change', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
columns_to_drop = ['objectid', 'unit','change', '1970', '1971', '1972',
       '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
       '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
       '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '2020', '2021']

# %%
df_temp = df_temp.drop(columns_to_drop,axis='columns')

# %%
df_temp.dtypes
# Out:
# country_name    object
# 1999            object
# 2000            object
# 2001            object
# 2002            object
# 2003            object
# 2004            object
# 2005            object
# 2006            object
# 2007            object
# 2008            object
# 2009            object
# 2010            object
# 2011            object
# 2012            object
# 2013            object
# 2014            object
# 2015            object
# 2016            object
# 2017            object
# 2018            object
# 2019            object
# dtype: object

# %%
df_temp
# Out:
#                      country_name     1999     2000     2001     2002  \
# 0    Afghanistan, Islamic Rep. of    1.301    1.109    1.366    1.384
# 1                         Albania    0.722    1.112    1.555    0.492
# 2                         Algeria    1.456    0.798    1.827    1.222
# 3                  American Samoa    0.243     0.67    0.948    1.196
# 4        Andorra, Principality of     1.02    1.015    1.476    0.828
# ..                            ...      ...      ...      ...      ...
# 222                Western Sahara    0.935    0.865    1.255    1.179
# 223                         World    0.787    0.732    0.833    1.018
# 224                Yemen, Rep. of  Unknown  Unknown  Unknown  Unknown
# 225                        Zambia    0.418    0.311    0.501    0.956
# 226                      Zimbabwe     0.09    -0.34     0.03    0.438
#
#         2003     2004     2005     2006     2007  ...     2010     2011  \
# ...

# %%
columns_to_process = df_temp.columns[1:]
#Replace the decimal point with a comma in each of those columns
for column in columns_to_process: 
    df_temp[column] = df_temp[column].astype(float, exceptErrors = coerce)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[315], line 4
#       2 #Replace the decimal point with a comma in each of those columns
#       3 for column in columns_to_process:
# ----> 4     df_temp[column] = df_temp[column].astype(float, exceptErrors = coerce)
#
# NameError: name 'coerce' is not defined

# %%
df_temp
# Out:
#                      country_name     1999     2000     2001     2002  \
# 0    Afghanistan, Islamic Rep. of    1.301    1.109    1.366    1.384
# 1                         Albania    0.722    1.112    1.555    0.492
# 2                         Algeria    1.456    0.798    1.827    1.222
# 3                  American Samoa    0.243     0.67    0.948    1.196
# 4        Andorra, Principality of     1.02    1.015    1.476    0.828
# ..                            ...      ...      ...      ...      ...
# 222                Western Sahara    0.935    0.865    1.255    1.179
# 223                         World    0.787    0.732    0.833    1.018
# 224                Yemen, Rep. of  Unknown  Unknown  Unknown  Unknown
# 225                        Zambia    0.418    0.311    0.501    0.956
# 226                      Zimbabwe     0.09    -0.34     0.03    0.438
#
#         2003     2004     2005     2006     2007  ...     2010     2011  \
# ...

# %%
df_temp.dtypes
# Out:
# country_name    object
# 1999            object
# 2000            object
# 2001            object
# 2002            object
# 2003            object
# 2004            object
# 2005            object
# 2006            object
# 2007            object
# 2008            object
# 2009            object
# 2010            object
# 2011            object
# 2012            object
# 2013            object
# 2014            object
# 2015            object
# 2016            object
# 2017            object
# 2018            object
# 2019            object
# dtype: object

# %%
columns_to_process = df_temp.columns[1:]
# Replace the comma with a decimal point in each of those columns
for column in columns_to_process: df_temp[column] = df_temp[column].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[242], line 3
#       1 columns_to_process = df_temp.columns[1:]
#       2 # Replace the comma with a decimal point in each of those columns
# ----> 3 for column in columns_to_process: df_temp[column] = df_temp[column].astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
df_temp = df_temp[columns_to_process].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 df_temp = df_temp[columns_to_process].astype(float)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
# ...

# %%
df_temp.to_csv('data_without_country_code_temp.csv', index=False)
